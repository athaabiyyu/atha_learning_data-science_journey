# %%
# membuat model regresi linear sederhana

import numpy as np

# data tiruan
np.random.seed(42)
x = 2 * np.random.rand(100, 1)
y = 4 + 3 * x + np.random.randn(100, 1)

# tambahkan 1 kolom untuk bias / intercept kedalam data x
X_bias = np.c_[np.ones((100, 1)), x]

# inisialisasi parameter
theta = np.random.randn(2, 1)
alpha = 0.1
iterations = 1000
m = len(y)

# gradient descent
for _ in range (iterations) :
       gradient = 2/m * X_bias.T.dot(X_bias.dot(theta) - y)
       theta -= alpha * gradient
       
# prediksi
y_pred = X_bias.dot(theta)

# hitung MSE dan R^2
mse = np.mean((y_pred - y) ** 2)
ss_red = np.sum((y - y_pred) ** 2)
ss_tot = np.sum((y - np.mean(y)) ** 2)
r2 = 1 - (ss_red / ss_tot)

print("Parameter (theta):", theta)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R^2):", r2)
# Out:
# Parameter (theta): [[4.21509616]
#  [2.77011339]]
# Mean Squared Error (MSE): 0.806584563967053
# R-squared (R^2): 0.7692735413614225
